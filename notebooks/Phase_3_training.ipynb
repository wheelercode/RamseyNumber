# %% [markdown]
# # Phase 3 Training
#
# Train a fresh policy from a curriculum containing 80% archived sub-400 colorings and 20% random colorings. No Phase 1 or Phase 2 weights are loaded.

# %%
# Imports and Project Paths

# %matplotlib inline

from pathlib import Path
from time import perf_counter

import matplotlib.pyplot as plt
import numpy as np

from ramsey import (
    RArchiveConstruction,
    REnvironment,
    REnvironmentConfig,
    RGraph,
    RMixedConstruction,
    RMonochromaticObjective,
    RProblem,
    RRandomConstruction,
    RSQLiteArchive,
    RTabuMemory,
    RTabuMemoryConfig,
)
from ramsey.RPlot import plot_coloring_histogram
from ramsey.nn import (
    RCheckpointSchedule,
    RModelConfig,
    RPPOConfig,
    RPPOTrainer,
    RPairPolicyValueNetwork,
    RRolloutConfig,
    RRolloutReward,
    RTrainingConfig,
    create_numpy_generator,
    create_optimizer,
    load_training_checkpoint,
    resolve_torch_device,
    seed_torch,
)

project_root = Path.cwd().resolve()

if project_root.name == "notebooks":
    project_root = project_root.parent

if not (project_root / "ramsey").is_dir():
    raise RuntimeError(
        "Run this notebook from the RamseyNumber root or notebooks directory."
    )

# %%
# Phase 3 Experiment Configuration

RANDOM_SEED = 202_608_053
N_VERTICES = 43
RUN_NAME = "phase-3-sub-400-curriculum"

TRAINING_ITERATIONS = 250
CHECKPOINT_INTERVAL = 10
ROLLOUT_STEPS = 128

ARCHIVE_SCORE_LIMIT = 399
MINIMUM_ARCHIVE_COLORINGS = 500
ARCHIVE_SEED_PROBABILITY = 0.80
RANDOM_SEED_PROBABILITY = 0.20

EDGE_TABU_TENURE = 20
VISITED_STATE_WINDOW = 2_000

DATABASE_PATH = (
    project_root
    / "data"
    / "ramsey_colorings.sqlite3"
)

CHECKPOINT_DIRECTORY = (
    project_root
    / "checkpoints"
    / "phase_3"
)

# Leave as None to create a fresh Phase 3 network. Only use a
# checkpoint created by this notebook when resuming Phase 3.
RESUME_PHASE_3_CHECKPOINT: Path | None = None
NEW_LEARNING_RATE: float | None = None

# %%
# Runtime, Problem, and Graph

rng = create_numpy_generator(
    RANDOM_SEED
)

seed_torch(
    RANDOM_SEED
)

device = resolve_torch_device()

graph_start = perf_counter()

problem = RProblem.r55(
    n_vertices=N_VERTICES,
)

graph = RGraph(
    problem
)

graph_elapsed = (
    perf_counter()
    - graph_start
)

print("Project root:", project_root)
print("Device:", device)
print("Problem:", problem)
print("Edges:", f"{graph.number_of_edges:,}")
print("Graph construction:", f"{graph_elapsed:.3f} seconds")
# Out:
# Project root: C:\code\RamseyNumber
# Device: cuda:0
# Problem: RProblem(n_vertices=43, forbidden_clique_sizes=(5, 5))
# Edges: 903
# Graph construction: 1.463 seconds

# %%
# Model, Rollout, and PPO Configuration

model_config = RModelConfig(
    input_size=3,
    hidden_size=64,
    number_of_layers=4,
    dropout=0.0,
)

rollout_config = RRolloutConfig(
    rollout_steps=ROLLOUT_STEPS,
    discount=0.995,
    gae_lambda=0.95,
    reward_scale=10.0,
    reward_source=RRolloutReward.EXACT_SCORE,
    normalize_advantages=True,
)

ppo_config = RPPOConfig(
    update_epochs=4,
    minibatch_size=16,
    clip_ratio=0.20,
    value_loss_weight=0.00,
    entropy_weight=0.001,
    maximum_gradient_norm=0.50,
    learning_rate=1.0e-4,
    target_kl=0.02,
)

# %%
# Create a Fresh Phase 3 Model or Resume Phase 3

if RESUME_PHASE_3_CHECKPOINT is None:
    network = RPairPolicyValueNetwork(
        graph,
        model_config,
    ).to(device)

    optimizer = create_optimizer(
        network,
        ppo_config,
    )

    start_iteration = 0

    print("Created a fresh Phase 3 network.")
else:
    checkpoint_path = RESUME_PHASE_3_CHECKPOINT.resolve()
    checkpoint_root = CHECKPOINT_DIRECTORY.resolve()

    if checkpoint_root not in checkpoint_path.parents:
        raise ValueError(
            "Phase 3 may only resume from checkpoints/phase_3."
        )

    restored = load_training_checkpoint(
        checkpoint_path,
        graph=graph,
        device=device,
        rng=rng,
        new_learning_rate=NEW_LEARNING_RATE,
    )

    network = restored.network
    optimizer = restored.optimizer
    model_config = restored.model_config
    rollout_config = restored.rollout_config
    ppo_config = restored.ppo_config
    start_iteration = restored.completed_iteration + 1

    print("Restored Phase 3 checkpoint:", checkpoint_path)

print("Starting iteration:", start_iteration)
print("Parameters:", f"{network.trainable_parameter_count:,}")
print("Learning rate:", optimizer.param_groups[0]["lr"])
print("Rollout steps:", rollout_config.rollout_steps)
# Out:
# Created a fresh Phase 3 network.
# Starting iteration: 0
# Parameters: 134,338
# Learning rate: 0.0001
# Rollout steps: 128

# %%
# Open and Validate the Phase 3 Curriculum Archive

existing_archive = globals().get("archive")

if existing_archive is not None:
    existing_archive.close()

archive = RSQLiteArchive(
    DATABASE_PATH
)

eligible_archive_count = (
    archive.coloring_count_in_score_range(
        maximum_score=ARCHIVE_SCORE_LIMIT,
        graph=graph,
    )
)

if eligible_archive_count < MINIMUM_ARCHIVE_COLORINGS:
    archive.close()

    raise RuntimeError(
        f"Phase 3 requires at least {MINIMUM_ARCHIVE_COLORINGS} "
        f"distinct sub-400 colorings; found {eligible_archive_count}."
    )

print("Database:", DATABASE_PATH.resolve())
print("Distinct sub-400 colorings:", eligible_archive_count)
print("Database best:", archive.best_score(graph))
# Out:
# Database: C:\code\RamseyNumber\data\ramsey_colorings.sqlite3
# Distinct sub-400 colorings: 896
# Database best: 278

# %%
# Mixed Curriculum and Search Environment

archive_construction = RArchiveConstruction(
    archive=archive,
    rng=rng,
    maximum_score=ARCHIVE_SCORE_LIMIT,
)

random_construction = RRandomConstruction(
    rng
)

construction = RMixedConstruction(
    constructions=(
        archive_construction,
        random_construction,
    ),
    probabilities=(
        ARCHIVE_SEED_PROBABILITY,
        RANDOM_SEED_PROBABILITY,
    ),
    rng=rng,
    construction_name="phase-3-mixed-curriculum",
)

objective = RMonochromaticObjective()

memory = RTabuMemory(
    number_of_edges=graph.number_of_edges,
    config=RTabuMemoryConfig(
        edge_tenure=EDGE_TABU_TENURE,
        visited_state_window=VISITED_STATE_WINDOW,
    ),
)

environment = REnvironment(
    graph=graph,
    objective=objective,
    memory=memory,
    config=REnvironmentConfig(
        max_steps=rollout_config.rollout_steps,
        use_aspiration=True,
    ),
)

print("Construction:", construction.name)
print("Archive source:", archive_construction.name)
print("Archive probability:", ARCHIVE_SEED_PROBABILITY)
print("Random probability:", RANDOM_SEED_PROBABILITY)
# Out:
# Construction: phase-3-mixed-curriculum
# Archive source: archive-score-any-to-399
# Archive probability: 0.8
# Random probability: 0.2

# %%
# Assemble the Phase 3 Trainer

trainer = RPPOTrainer(
    graph=graph,
    construction=construction,
    environment=environment,
    network=network,
    optimizer=optimizer,
    device=device,
    rng=rng,
    rollout_config=rollout_config,
    ppo_config=ppo_config,
    archive=archive,
)

checkpoint_schedule = RCheckpointSchedule(
    directory=CHECKPOINT_DIRECTORY,
    interval=CHECKPOINT_INTERVAL,
    save_final=True,
)

training_config = RTrainingConfig(
    run_name=RUN_NAME,
    iterations=TRAINING_ITERATIONS,
    start_iteration=start_iteration,
    stop_on_solution=True,
)

print("Iterations:", training_config.iterations)
print("Checkpoint directory:", CHECKPOINT_DIRECTORY.resolve())
# Out:
# Iterations: 250
# Checkpoint directory: C:\code\RamseyNumber\checkpoints\phase_3

# %%
# Source-Aware Progress Reporting

def report_training_iteration(
    iteration_result,
) -> None:
    metrics = iteration_result.metrics

    if metrics is None:
        metric_text = "no parameter update"
    else:
        metric_text = (
            f"policy={metrics.policy_loss:+.4f} | "
            f"value={metrics.value_loss:.4f} | "
            f"entropy={metrics.entropy:.4f} | "
            f"KL={metrics.approximate_kl:.6f} | "
            f"clipped={metrics.clipped_fraction:.4f}"
        )

    checkpoint_text = ""

    if iteration_result.checkpoint_path is not None:
        checkpoint_text = (
            f" | checkpoint={iteration_result.checkpoint_path.name}"
        )

    database_best_text = (
        " NEW DATABASE BEST"
        if iteration_result.new_archive_best
        else ""
    )

    print(
        f"Iteration {iteration_result.iteration:6d} | "
        f"source={iteration_result.construction_source:24s} | "
        f"initial={iteration_result.initial_score:5d} | "
        f"final={iteration_result.final_score:5d} | "
        f"best={iteration_result.best_score:5d} | "
        f"reward={iteration_result.total_scaled_reward:+9.3f} | "
        f"{metric_text}"
        f"{database_best_text}"
        f"{checkpoint_text}"
    )

# %%
# Run Phase 3 Training

training_start = perf_counter()

training_result = trainer.run(
    training_config,
    checkpoint_schedule=checkpoint_schedule,
    observer=report_training_iteration,
)

training_elapsed = (
    perf_counter()
    - training_start
)

print()
print("Completed iterations:", training_result.completed_iterations)
print("Best score:", training_result.best_score)
print("Solved:", training_result.solved)
print("Total time:", f"{training_elapsed:.3f} seconds")
print(
    "Mean time per iteration:",
    f"{training_elapsed / training_result.completed_iterations:.3f} seconds",
)
# Out:
# Iteration      0 | source=archive-score-any-to-399 | initial=  316 | final= 1141 | best=  316 | reward=  -82.500 | policy=-0.0155 | value=116.4614 | entropy=6.7780 | KL=0.010512 | clipped=0.1113
# Iteration      1 | source=archive-score-any-to-399 | initial=  299 | final= 1286 | best=  299 | reward=  -98.700 | policy=-0.0129 | value=162.4411 | entropy=6.7827 | KL=0.008605 | clipped=0.0957
# Iteration      2 | source=archive-score-any-to-399 | initial=  346 | final= 1182 | best=  346 | reward=  -83.600 | policy=-0.0021 | value=116.5231 | entropy=6.7846 | KL=0.000546 | clipped=0.0000
# Iteration      3 | source=archive-score-any-to-399 | initial=  314 | final=  932 | best=  314 | reward=  -61.800 | policy=-0.0047 | value=74.6358 | entropy=6.7840 | KL=0.001008 | clipped=0.0000
# Iteration      4 | source=archive-score-any-to-399 | initial=  307 | final= 1076 | best=  307 | reward=  -76.900 | policy=+0.0010 | value=92.9047 | entropy=6.7757 | KL=0.000511 | clipped=0.0000
# Iteration      5 | source=archive-score-any-to-399 | initial=  326 | final= 1134 | best=  326 | reward=  -80.800 | policy=-0.0058 | value=124.0216 | entropy=6.7833 | KL=0.002507 | clipped=0.0000
# Iteration      6 | source=archive-score-any-to-399 | initial=  342 | final=  854 | best=  342 | reward=  -51.200 | policy=-0.0018 | value=52.3057 | entropy=6.7851 | KL=0.000159 | clipped=0.0000
# Iteration      7 | source=archive-score-any-to-399 | initial=  350 | final= 1284 | best=  347 | reward=  -93.400 | policy=+0.0001 | value=144.2970 | entropy=6.7848 | KL=0.000018 | clipped=0.0000
# Iteration      8 | source=archive-score-any-to-399 | initial=  356 | final= 1103 | best=  356 | reward=  -74.700 | policy=-0.0002 | value=91.0788 | entropy=6.7851 | KL=0.000045 | clipped=0.0000
# Iteration      9 | source=archive-score-any-to-399 | initial=  310 | final=  946 | best=  309 | reward=  -63.600 | policy=-0.0012 | value=88.8443 | entropy=6.7850 | KL=0.000131 | clipped=0.0000 | checkpoint=ramsey_policy_iteration_000009.pt
# Iteration     10 | source=archive-score-any-to-399 | initial=  342 | final=  958 | best=  342 | reward=  -61.600 | policy=-0.0108 | value=66.5834 | entropy=6.7730 | KL=0.008346 | clipped=0.1484
# Iteration     11 | source=archive-score-any-to-399 | initial=  324 | final= 1085 | best=  324 | reward=  -76.100 | policy=-0.0337 | value=91.0604 | entropy=6.7833 | KL=0.011098 | clipped=0.1699
# Iteration     12 | source=random                   | initial= 2350 | final= 1890 | best= 1530 | reward=  +46.000 | policy=-0.0001 | value=155.6303 | entropy=6.7882 | KL=0.000001 | clipped=0.0000
# Iteration     13 | source=archive-score-any-to-399 | initial=  322 | final= 1211 | best=  322 | reward=  -88.900 | policy=-0.0000 | value=125.8874 | entropy=6.7852 | KL=0.000001 | clipped=0.0000
# Iteration     14 | source=archive-score-any-to-399 | initial=  309 | final= 1037 | best=  309 | reward=  -72.800 | policy=-0.0000 | value=92.5544 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     15 | source=archive-score-any-to-399 | initial=  352 | final= 1186 | best=  352 | reward=  -83.400 | policy=-0.0003 | value=152.9602 | entropy=6.7852 | KL=0.000002 | clipped=0.0000
# Iteration     16 | source=archive-score-any-to-399 | initial=  318 | final= 1087 | best=  318 | reward=  -76.900 | policy=-0.0001 | value=95.3930 | entropy=6.7852 | KL=0.000001 | clipped=0.0000
# Iteration     17 | source=archive-score-any-to-399 | initial=  320 | final= 1110 | best=  320 | reward=  -79.000 | policy=-0.0000 | value=145.6255 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     18 | source=archive-score-any-to-399 | initial=  328 | final= 1039 | best=  328 | reward=  -71.100 | policy=-0.0000 | value=78.4369 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     19 | source=archive-score-any-to-399 | initial=  324 | final= 1161 | best=  324 | reward=  -83.700 | policy=-0.0001 | value=115.4143 | entropy=6.7852 | KL=0.000000 | clipped=0.0000 | checkpoint=ramsey_policy_iteration_000019.pt
# Iteration     20 | source=archive-score-any-to-399 | initial=  342 | final= 1021 | best=  341 | reward=  -67.900 | policy=-0.0001 | value=97.4977 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     21 | source=archive-score-any-to-399 | initial=  312 | final= 1010 | best=  309 | reward=  -69.800 | policy=-0.0000 | value=77.6745 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     22 | source=archive-score-any-to-399 | initial=  322 | final= 1110 | best=  320 | reward=  -78.800 | policy=-0.0001 | value=106.6225 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     23 | source=archive-score-any-to-399 | initial=  301 | final= 1041 | best=  301 | reward=  -74.000 | policy=-0.0002 | value=92.9243 | entropy=6.7852 | KL=0.000001 | clipped=0.0000
# Iteration     24 | source=random                   | initial= 1811 | final= 1619 | best= 1425 | reward=  +19.200 | policy=-0.0006 | value=60.8101 | entropy=6.7871 | KL=0.000005 | clipped=0.0000
# Iteration     25 | source=archive-score-any-to-399 | initial=  323 | final=  965 | best=  323 | reward=  -64.200 | policy=+0.0000 | value=66.7954 | entropy=6.7852 | KL=0.000001 | clipped=0.0000
# Iteration     26 | source=archive-score-any-to-399 | initial=  329 | final= 1019 | best=  329 | reward=  -69.000 | policy=-0.0000 | value=70.5819 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     27 | source=archive-score-any-to-399 | initial=  324 | final= 1204 | best=  324 | reward=  -88.000 | policy=-0.0001 | value=127.6906 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     28 | source=random                   | initial= 1984 | final= 2234 | best= 1798 | reward=  -25.000 | policy=-0.0002 | value=49.0960 | entropy=6.7862 | KL=0.000002 | clipped=0.0000
# Iteration     29 | source=random                   | initial= 1719 | final= 2169 | best= 1719 | reward=  -45.000 | policy=-0.0050 | value=73.1383 | entropy=6.7844 | KL=0.000566 | clipped=0.0039 | checkpoint=ramsey_policy_iteration_000029.pt
# Iteration     30 | source=archive-score-any-to-399 | initial=  314 | final= 1138 | best=  314 | reward=  -82.400 | policy=+0.0030 | value=117.1208 | entropy=6.7805 | KL=0.001782 | clipped=0.0156
# Iteration     31 | source=archive-score-any-to-399 | initial=  345 | final= 1101 | best=  345 | reward=  -75.600 | policy=-0.0145 | value=155.7309 | entropy=6.7848 | KL=0.003319 | clipped=0.0254
# Iteration     32 | source=archive-score-any-to-399 | initial=  328 | final=  998 | best=  328 | reward=  -67.000 | policy=-0.0010 | value=91.6694 | entropy=6.7851 | KL=0.000036 | clipped=0.0000
# Iteration     33 | source=archive-score-any-to-399 | initial=  303 | final= 1079 | best=  303 | reward=  -77.600 | policy=-0.0000 | value=93.8582 | entropy=6.7852 | KL=0.000001 | clipped=0.0000
# Iteration     34 | source=archive-score-any-to-399 | initial=  335 | final=  972 | best=  335 | reward=  -63.700 | policy=+0.0000 | value=66.3862 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     35 | source=archive-score-any-to-399 | initial=  334 | final= 1059 | best=  334 | reward=  -72.500 | policy=-0.0001 | value=96.4495 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     36 | source=archive-score-any-to-399 | initial=  350 | final= 1151 | best=  350 | reward=  -80.100 | policy=-0.0001 | value=109.9695 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     37 | source=archive-score-any-to-399 | initial=  320 | final= 1078 | best=  320 | reward=  -75.800 | policy=-0.0003 | value=92.0228 | entropy=6.7852 | KL=0.000001 | clipped=0.0000
# Iteration     38 | source=archive-score-any-to-399 | initial=  315 | final= 1003 | best=  315 | reward=  -68.800 | policy=-0.0001 | value=88.0462 | entropy=6.7852 | KL=0.000001 | clipped=0.0000
# Iteration     39 | source=archive-score-any-to-399 | initial=  335 | final= 1061 | best=  335 | reward=  -72.600 | policy=-0.0002 | value=109.2893 | entropy=6.7852 | KL=0.000001 | clipped=0.0000 | checkpoint=ramsey_policy_iteration_000039.pt
# Iteration     40 | source=archive-score-any-to-399 | initial=  326 | final= 1404 | best=  326 | reward= -107.800 | policy=-0.0009 | value=194.1309 | entropy=6.7851 | KL=0.000027 | clipped=0.0000
# Iteration     41 | source=archive-score-any-to-399 | initial=  331 | final= 1306 | best=  331 | reward=  -97.500 | policy=-0.0018 | value=171.0621 | entropy=6.7794 | KL=0.003734 | clipped=0.0000
# Iteration     42 | source=archive-score-any-to-399 | initial=  311 | final= 1472 | best=  311 | reward= -116.100 | policy=-0.0308 | value=249.2355 | entropy=6.7819 | KL=0.011253 | clipped=0.1738
# Iteration     43 | source=random                   | initial= 1871 | final= 1445 | best= 1309 | reward=  +42.600 | policy=-0.0003 | value=54.1133 | entropy=6.7885 | KL=0.000004 | clipped=0.0000
# Iteration     44 | source=random                   | initial= 1887 | final= 1620 | best= 1514 | reward=  +26.700 | policy=-0.0087 | value=59.4212 | entropy=6.7832 | KL=0.002978 | clipped=0.0352
# Iteration     45 | source=random                   | initial= 2182 | final= 2381 | best= 2099 | reward=  -19.900 | policy=-0.0287 | value=127.9656 | entropy=6.7830 | KL=0.015247 | clipped=0.2715
# Iteration     46 | source=archive-score-any-to-399 | initial=  392 | final= 1225 | best=  392 | reward=  -83.300 | policy=+0.0000 | value=110.0966 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     47 | source=random                   | initial= 1667 | final= 1939 | best= 1646 | reward=  -27.200 | policy=-0.0006 | value=46.0341 | entropy=6.7853 | KL=0.000004 | clipped=0.0000
# Iteration     48 | source=archive-score-any-to-399 | initial=  313 | final= 1062 | best=  313 | reward=  -74.900 | policy=-0.0004 | value=96.0924 | entropy=6.7851 | KL=0.000008 | clipped=0.0000
# Iteration     49 | source=random                   | initial= 1854 | final= 2078 | best= 1681 | reward=  -22.400 | policy=-0.0016 | value=63.8082 | entropy=6.7860 | KL=0.000147 | clipped=0.0000 | checkpoint=ramsey_policy_iteration_000049.pt
# Iteration     50 | source=random                   | initial= 1816 | final= 1470 | best= 1458 | reward=  +34.600 | policy=-0.0086 | value=89.8955 | entropy=6.7870 | KL=0.000886 | clipped=0.0000
# Iteration     51 | source=archive-score-any-to-399 | initial=  322 | final=  961 | best=  322 | reward=  -63.900 | policy=-0.0002 | value=74.3740 | entropy=6.7852 | KL=0.000001 | clipped=0.0000
# Iteration     52 | source=archive-score-any-to-399 | initial=  366 | final= 1084 | best=  366 | reward=  -71.800 | policy=-0.0002 | value=91.2770 | entropy=6.7852 | KL=0.000001 | clipped=0.0000
# Iteration     53 | source=random                   | initial= 1991 | final= 1755 | best= 1755 | reward=  +23.600 | policy=-0.0001 | value=234.2322 | entropy=6.7860 | KL=0.000000 | clipped=0.0000
# Iteration     54 | source=archive-score-any-to-399 | initial=  314 | final= 1135 | best=  314 | reward=  -82.100 | policy=+0.0000 | value=117.0312 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     55 | source=archive-score-any-to-399 | initial=  368 | final= 1078 | best=  368 | reward=  -71.000 | policy=-0.0000 | value=86.8749 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     56 | source=random                   | initial= 1505 | final= 1494 | best= 1371 | reward=   +1.100 | policy=-0.0000 | value=33.2946 | entropy=6.7860 | KL=0.000000 | clipped=0.0000
# Iteration     57 | source=archive-score-any-to-399 | initial=  334 | final=  972 | best=  334 | reward=  -63.800 | policy=-0.0001 | value=69.6051 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     58 | source=archive-score-any-to-399 | initial=  328 | final= 1059 | best=  328 | reward=  -73.100 | policy=+0.0000 | value=88.5347 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     59 | source=archive-score-any-to-399 | initial=  314 | final=  961 | best=  314 | reward=  -64.700 | policy=-0.0000 | value=75.7884 | entropy=6.7852 | KL=0.000000 | clipped=0.0000 | checkpoint=ramsey_policy_iteration_000059.pt
# Iteration     60 | source=archive-score-any-to-399 | initial=  316 | final= 1058 | best=  316 | reward=  -74.200 | policy=-0.0001 | value=103.8998 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     61 | source=random                   | initial= 1513 | final= 1197 | best= 1155 | reward=  +31.600 | policy=-0.0001 | value=36.7160 | entropy=6.7875 | KL=0.000001 | clipped=0.0000
# Iteration     62 | source=archive-score-any-to-399 | initial=  348 | final= 1088 | best=  348 | reward=  -74.000 | policy=-0.0001 | value=87.4016 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     63 | source=archive-score-any-to-399 | initial=  353 | final= 1044 | best=  353 | reward=  -69.100 | policy=-0.0001 | value=97.6637 | entropy=6.7852 | KL=0.000001 | clipped=0.0000
# Iteration     64 | source=archive-score-any-to-399 | initial=  301 | final= 1052 | best=  301 | reward=  -75.100 | policy=-0.0000 | value=105.5483 | entropy=6.7851 | KL=0.000002 | clipped=0.0000
# Iteration     65 | source=random                   | initial= 1635 | final= 1527 | best= 1447 | reward=  +10.800 | policy=-0.0001 | value=24.9884 | entropy=6.7866 | KL=0.000002 | clipped=0.0000
# Iteration     66 | source=archive-score-any-to-399 | initial=  328 | final= 1041 | best=  328 | reward=  -71.300 | policy=-0.0010 | value=87.7672 | entropy=6.7849 | KL=0.000087 | clipped=0.0000
# Iteration     67 | source=archive-score-any-to-399 | initial=  328 | final= 1067 | best=  328 | reward=  -73.900 | policy=-0.0011 | value=81.3976 | entropy=6.7846 | KL=0.000158 | clipped=0.0000
# Iteration     68 | source=random                   | initial= 1477 | final= 1462 | best= 1437 | reward=   +1.500 | policy=-0.0001 | value=44.7160 | entropy=6.7858 | KL=0.000010 | clipped=0.0000
# Iteration     69 | source=archive-score-any-to-399 | initial=  324 | final= 1276 | best=  324 | reward=  -95.200 | policy=-0.0001 | value=170.0220 | entropy=6.7851 | KL=0.000000 | clipped=0.0000 | checkpoint=ramsey_policy_iteration_000069.pt
# Iteration     70 | source=archive-score-any-to-399 | initial=  314 | final= 1232 | best=  314 | reward=  -91.800 | policy=+0.0000 | value=142.5487 | entropy=6.7851 | KL=0.000000 | clipped=0.0000
# Iteration     71 | source=archive-score-any-to-399 | initial=  352 | final= 1138 | best=  352 | reward=  -78.600 | policy=-0.0000 | value=94.7104 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     72 | source=archive-score-any-to-399 | initial=  316 | final= 1198 | best=  316 | reward=  -88.200 | policy=-0.0000 | value=128.9474 | entropy=6.7852 | KL=0.000000 | clipped=0.0000
# Iteration     73 | source=archive-score-any-to-399 | initial=  334 | final= 1072 | best=  334 | reward=  -73.800 | policy=-0.0002 | value=85.6324 | entropy=6.7852 | KL=0.000001 | clipped=0.0000
# Iteration     74 | source=archive-score-any-to-399 | initial=  345 | final= 1172 | best=  345 | reward=  -82.700 | policy=-0.0003 | value=140.7379 | entropy=6.7851 | KL=0.000009 | clipped=0.0000
# Iteration     75 | source=archive-score-any-to-399 | initial=  368 | final= 1076 | best=  368 | reward=  -70.800 | policy=+0.0000 | value=87.5012 | entropy=6.7850 | KL=0.000001 | clipped=0.0000
# Iteration     76 | source=random                   | initial= 2529 | final= 2201 | best= 2171 | reward=  +32.800 | policy=-0.0082 | value=160.7921 | entropy=6.7830 | KL=0.003199 | clipped=0.0547
# Iteration     77 | source=archive-score-any-to-399 | initial=  310 | final= 1052 | best=  310 | reward=  -74.200 | policy=-0.0011 | value=82.4718 | entropy=6.7222 | KL=0.008661 | clipped=0.1289
# Iteration     78 | source=archive-score-any-to-399 | initial=  307 | final= 1781 | best=  307 | reward= -147.400 | policy=-0.0113 | value=391.4843 | entropy=6.7519 | KL=0.013424 | clipped=0.2812
# Iteration     79 | source=random                   | initial= 1893 | final= 1538 | best= 1495 | reward=  +35.500 | policy=+0.0007 | value=38.1749 | entropy=6.7854 | KL=0.000130 | clipped=0.0000 | checkpoint=ramsey_policy_iteration_000079.pt
# Iteration     80 | source=archive-score-any-to-399 | initial=  328 | final=  951 | best=  328 | reward=  -62.300 | policy=-0.0024 | value=82.5828 | entropy=6.7766 | KL=0.005164 | clipped=0.0762
# Iteration     81 | source=archive-score-any-to-399 | initial=  330 | final=  990 | best=  330 | reward=  -66.000 | policy=-0.0004 | value=88.1699 | entropy=6.7754 | KL=0.000890 | clipped=0.0000
# Iteration     82 | source=archive-score-any-to-399 | initial=  304 | final= 1168 | best=  304 | reward=  -86.400 | policy=-0.0125 | value=115.1672 | entropy=6.7492 | KL=0.010472 | clipped=0.1797
# Iteration     83 | source=archive-score-any-to-399 | initial=  347 | final= 1157 | best=  347 | reward=  -81.000 | policy=-0.0202 | value=115.3430 | entropy=6.7786 | KL=0.013617 | clipped=0.2578
# Iteration     84 | source=random                   | initial= 2383 | final= 2442 | best= 2170 | reward=   -5.900 | policy=-0.0121 | value=117.8197 | entropy=6.7838 | KL=0.002925 | clipped=0.0176
# Iteration     85 | source=archive-score-any-to-399 | initial=  349 | final=  973 | best=  349 | reward=  -62.400 | policy=+0.0002 | value=65.5416 | entropy=6.7850 | KL=0.000010 | clipped=0.0000
# Iteration     86 | source=archive-score-any-to-399 | initial=  334 | final= 1067 | best=  334 | reward=  -73.300 | policy=-0.0025 | value=83.5116 | entropy=6.7851 | KL=0.000078 | clipped=0.0000
# Iteration     87 | source=archive-score-any-to-399 | initial=  335 | final= 1009 | best=  335 | reward=  -67.400 | policy=-0.0003 | value=77.3994 | entropy=6.7851 | KL=0.000012 | clipped=0.0000
# Iteration     88 | source=archive-score-any-to-399 | initial=  349 | final= 1220 | best=  349 | reward=  -87.100 | policy=-0.0001 | value=142.1989 | entropy=6.7851 | KL=0.000001 | clipped=0.0000
# Iteration     89 | source=archive-score-any-to-399 | initial=  295 | final= 1026 | best=  295 | reward=  -73.100 | policy=-0.0001 | value=79.5337 | entropy=6.7851 | KL=0.000002 | clipped=0.0000 | checkpoint=ramsey_policy_iteration_000089.pt
# Iteration     90 | source=archive-score-any-to-399 | initial=  292 | final= 1084 | best=  292 | reward=  -79.200 | policy=-0.0009 | value=107.4812 | entropy=6.7851 | KL=0.000035 | clipped=0.0000
# Iteration     91 | source=random                   | initial= 1979 | final= 1996 | best= 1754 | reward=   -1.700 | policy=-0.0003 | value=61.5655 | entropy=6.7864 | KL=0.000019 | clipped=0.0000
# Iteration     92 | source=archive-score-any-to-399 | initial=  330 | final= 1113 | best=  330 | reward=  -78.300 | policy=-0.0072 | value=104.9358 | entropy=6.7747 | KL=0.008453 | clipped=0.1211
# Iteration     93 | source=archive-score-any-to-399 | initial=  314 | final= 1241 | best=  314 | reward=  -92.700 | policy=-0.0177 | value=155.0684 | entropy=6.7778 | KL=0.009844 | clipped=0.1582
# Iteration     94 | source=archive-score-any-to-399 | initial=  312 | final= 1118 | best=  312 | reward=  -80.600 | policy=-0.0124 | value=127.3970 | entropy=6.7758 | KL=0.004267 | clipped=0.0625
# Iteration     95 | source=archive-score-any-to-399 | initial=  334 | final= 1013 | best=  334 | reward=  -67.900 | policy=-0.0024 | value=75.9024 | entropy=6.7841 | KL=0.001385 | clipped=0.0078
# Iteration     96 | source=archive-score-any-to-399 | initial=  311 | final=  913 | best=  306 | reward=  -60.200 | policy=-0.0051 | value=66.8341 | entropy=6.7826 | KL=0.005992 | clipped=0.0723
# Iteration     97 | source=archive-score-any-to-399 | initial=  366 | final= 1276 | best=  366 | reward=  -91.000 | policy=-0.0108 | value=145.2013 | entropy=6.7794 | KL=0.010521 | clipped=0.1035
# Iteration     98 | source=archive-score-any-to-399 | initial=  328 | final= 1360 | best=  328 | reward= -103.200 | policy=-0.0150 | value=171.0613 | entropy=6.7569 | KL=0.011024 | clipped=0.1797
# Iteration     99 | source=archive-score-any-to-399 | initial=  298 | final= 1234 | best=  298 | reward=  -93.600 | policy=-0.0230 | value=128.9646 | entropy=6.7329 | KL=0.011475 | clipped=0.1914 | checkpoint=ramsey_policy_iteration_000099.pt
# Iteration    100 | source=archive-score-any-to-399 | initial=  361 | final=  967 | best=  361 | reward=  -60.600 | policy=-0.0027 | value=56.8393 | entropy=6.7524 | KL=0.016764 | clipped=0.2207
# Iteration    101 | source=archive-score-any-to-399 | initial=  353 | final=  966 | best=  353 | reward=  -61.300 | policy=+0.0087 | value=67.9649 | entropy=6.7420 | KL=0.021953 | clipped=0.2910
# Iteration    102 | source=archive-score-any-to-399 | initial=  334 | final= 1137 | best=  334 | reward=  -80.300 | policy=+0.0003 | value=106.6192 | entropy=6.7310 | KL=0.018312 | clipped=0.1953
# Iteration    103 | source=archive-score-any-to-399 | initial=  357 | final= 1121 | best=  357 | reward=  -76.400 | policy=-0.0199 | value=107.0433 | entropy=6.7357 | KL=0.015878 | clipped=0.2422
# Iteration    104 | source=archive-score-any-to-399 | initial=  298 | final=  903 | best=  298 | reward=  -60.500 | policy=-0.0019 | value=83.9432 | entropy=6.7167 | KL=0.010470 | clipped=0.1133
# Iteration    105 | source=archive-score-any-to-399 | initial=  308 | final= 1191 | best=  308 | reward=  -88.300 | policy=+0.0073 | value=156.9762 | entropy=6.7063 | KL=0.036348 | clipped=0.2500
# Iteration    106 | source=archive-score-any-to-399 | initial=  334 | final= 1009 | best=  334 | reward=  -67.500 | policy=-0.0134 | value=81.7127 | entropy=6.6181 | KL=0.013647 | clipped=0.2031
# Iteration    107 | source=archive-score-any-to-399 | initial=  347 | final= 1044 | best=  347 | reward=  -69.700 | policy=-0.0089 | value=84.3027 | entropy=6.5960 | KL=0.009833 | clipped=0.1543
# Iteration    108 | source=random                   | initial= 2290 | final= 1891 | best= 1857 | reward=  +39.900 | policy=-0.0226 | value=98.9884 | entropy=6.4026 | KL=0.018006 | clipped=0.2656
# Iteration    109 | source=archive-score-any-to-399 | initial=  354 | final= 1048 | best=  354 | reward=  -69.400 | policy=+0.0006 | value=80.9346 | entropy=6.5583 | KL=0.011427 | clipped=0.1484 | checkpoint=ramsey_policy_iteration_000109.pt
# Iteration    110 | source=archive-score-any-to-399 | initial=  330 | final=  949 | best=  330 | reward=  -61.900 | policy=+0.0026 | value=64.4727 | entropy=6.5166 | KL=0.017098 | clipped=0.1992
# Iteration    111 | source=archive-score-any-to-399 | initial=  329 | final=  883 | best=  329 | reward=  -55.400 | policy=-0.0014 | value=88.7986 | entropy=6.6353 | KL=0.008867 | clipped=0.1074
# Iteration    112 | source=archive-score-any-to-399 | initial=  351 | final= 1059 | best=  351 | reward=  -70.800 | policy=-0.0117 | value=85.9606 | entropy=6.6062 | KL=0.013006 | clipped=0.1953
# Iteration    113 | source=archive-score-any-to-399 | initial=  286 | final=  873 | best=  286 | reward=  -58.700 | policy=-0.0177 | value=61.8438 | entropy=6.5822 | KL=0.013813 | clipped=0.1992
# Iteration    114 | source=archive-score-any-to-399 | initial=  345 | final= 1047 | best=  345 | reward=  -70.200 | policy=-0.0178 | value=72.5206 | entropy=6.4299 | KL=0.011668 | clipped=0.1745
# Iteration    115 | source=archive-score-any-to-399 | initial=  303 | final= 1106 | best=  303 | reward=  -80.300 | policy=+0.0045 | value=103.2438 | entropy=6.4191 | KL=0.020018 | clipped=0.2070
# Iteration    116 | source=archive-score-any-to-399 | initial=  305 | final=  916 | best=  305 | reward=  -61.100 | policy=+0.0039 | value=64.6887 | entropy=6.4975 | KL=0.019728 | clipped=0.2930
# Iteration    117 | source=random                   | initial= 2160 | final= 1534 | best= 1490 | reward=  +62.600 | policy=+0.0170 | value=109.5199 | entropy=6.4345 | KL=0.024870 | clipped=0.3359
# Iteration    118 | source=archive-score-any-to-399 | initial=  340 | final= 1020 | best=  340 | reward=  -68.000 | policy=-0.0107 | value=82.8751 | entropy=6.5835 | KL=0.015464 | clipped=0.2305
# Iteration    119 | source=archive-score-any-to-399 | initial=  328 | final=  846 | best=  328 | reward=  -51.800 | policy=-0.0134 | value=45.4175 | entropy=6.5141 | KL=0.013313 | clipped=0.2070 | checkpoint=ramsey_policy_iteration_000119.pt
# Iteration    120 | source=archive-score-any-to-399 | initial=  353 | final=  892 | best=  353 | reward=  -53.900 | policy=+0.0163 | value=61.7147 | entropy=6.5547 | KL=0.029247 | clipped=0.3516
# Iteration    121 | source=archive-score-any-to-399 | initial=  355 | final=  811 | best=  355 | reward=  -45.600 | policy=-0.0078 | value=39.6801 | entropy=6.5858 | KL=0.016738 | clipped=0.2422
# Iteration    122 | source=archive-score-any-to-399 | initial=  352 | final=  926 | best=  352 | reward=  -57.400 | policy=-0.0183 | value=74.6651 | entropy=6.5974 | KL=0.024288 | clipped=0.3867
# Iteration    123 | source=archive-score-any-to-399 | initial=  318 | final= 1025 | best=  318 | reward=  -70.700 | policy=-0.0170 | value=87.2151 | entropy=6.5374 | KL=0.009510 | clipped=0.1328
# Iteration    124 | source=archive-score-any-to-399 | initial=  300 | final=  879 | best=  300 | reward=  -57.900 | policy=-0.0033 | value=74.1672 | entropy=6.5552 | KL=0.018727 | clipped=0.2539
# Iteration    125 | source=archive-score-any-to-399 | initial=  327 | final= 1052 | best=  327 | reward=  -72.500 | policy=-0.0081 | value=91.3531 | entropy=6.4944 | KL=0.013365 | clipped=0.2129
# Iteration    126 | source=archive-score-any-to-399 | initial=  326 | final= 1062 | best=  326 | reward=  -73.600 | policy=+0.0165 | value=99.0171 | entropy=6.5763 | KL=0.037658 | clipped=0.3047
# Iteration    127 | source=random                   | initial= 1798 | final= 1021 | best= 1021 | reward=  +77.700 | policy=-0.0204 | value=178.8291 | entropy=6.3804 | KL=0.018503 | clipped=0.2070
# Iteration    128 | source=archive-score-any-to-399 | initial=  350 | final=  885 | best=  350 | reward=  -53.500 | policy=+0.0063 | value=49.4686 | entropy=6.5554 | KL=0.016797 | clipped=0.2695
# Iteration    129 | source=archive-score-any-to-399 | initial=  334 | final=  783 | best=  334 | reward=  -44.900 | policy=-0.0018 | value=52.8145 | entropy=6.5599 | KL=0.012099 | clipped=0.2129 | checkpoint=ramsey_policy_iteration_000129.pt
# Iteration    130 | source=archive-score-any-to-399 | initial=  356 | final=  931 | best=  356 | reward=  -57.500 | policy=-0.0248 | value=79.3230 | entropy=6.5335 | KL=0.014043 | clipped=0.2520
# Iteration    131 | source=random                   | initial= 1843 | final= 1408 | best= 1310 | reward=  +43.500 | policy=-0.0176 | value=76.5113 | entropy=6.3133 | KL=0.013451 | clipped=0.2083
# Iteration    132 | source=archive-score-any-to-399 | initial=  339 | final=  840 | best=  339 | reward=  -50.100 | policy=-0.0202 | value=40.9938 | entropy=6.5135 | KL=0.014437 | clipped=0.2109
# Iteration    133 | source=archive-score-any-to-399 | initial=  331 | final=  837 | best=  331 | reward=  -50.600 | policy=+0.0053 | value=53.6017 | entropy=6.5996 | KL=0.013851 | clipped=0.1953
# Iteration    134 | source=archive-score-any-to-399 | initial=  309 | final=  957 | best=  309 | reward=  -64.800 | policy=-0.0095 | value=64.6111 | entropy=6.6370 | KL=0.011331 | clipped=0.1758
# Iteration    135 | source=archive-score-any-to-399 | initial=  322 | final=  857 | best=  322 | reward=  -53.500 | policy=-0.0187 | value=57.4474 | entropy=6.6206 | KL=0.011159 | clipped=0.1849
# Iteration    136 | source=random                   | initial= 1736 | final= 1201 | best= 1140 | reward=  +53.500 | policy=-0.0154 | value=56.0389 | entropy=6.3644 | KL=0.020719 | clipped=0.3281
# Iteration    137 | source=archive-score-any-to-399 | initial=  306 | final=  835 | best=  306 | reward=  -52.900 | policy=+0.0077 | value=49.4293 | entropy=6.5315 | KL=0.021100 | clipped=0.2500
# Iteration    138 | source=archive-score-any-to-399 | initial=  361 | final=  791 | best=  361 | reward=  -43.000 | policy=+0.0124 | value=36.4698 | entropy=6.4500 | KL=0.020935 | clipped=0.2266
# Iteration    139 | source=archive-score-any-to-399 | initial=  341 | final=  838 | best=  341 | reward=  -49.700 | policy=-0.0001 | value=55.1140 | entropy=6.5509 | KL=0.025099 | clipped=0.2930 | checkpoint=ramsey_policy_iteration_000139.pt
# Iteration    140 | source=archive-score-any-to-399 | initial=  298 | final=  782 | best=  298 | reward=  -48.400 | policy=-0.0138 | value=41.6307 | entropy=6.5396 | KL=0.037249 | clipped=0.3750
# Iteration    141 | source=archive-score-any-to-399 | initial=  325 | final=  788 | best=  325 | reward=  -46.300 | policy=+0.0144 | value=38.2244 | entropy=6.4502 | KL=0.024894 | clipped=0.3281
# Iteration    142 | source=random                   | initial= 1543 | final= 1112 | best= 1071 | reward=  +43.100 | policy=-0.0280 | value=55.3068 | entropy=6.3313 | KL=0.015003 | clipped=0.2383
# Iteration    143 | source=random                   | initial= 2050 | final=  987 | best=  968 | reward= +106.300 | policy=-0.0149 | value=196.8939 | entropy=6.2640 | KL=0.018314 | clipped=0.1927
# Iteration    144 | source=archive-score-any-to-399 | initial=  322 | final=  857 | best=  322 | reward=  -53.500 | policy=-0.0123 | value=50.9459 | entropy=6.5380 | KL=0.011456 | clipped=0.1895
# Iteration    145 | source=archive-score-any-to-399 | initial=  354 | final=  819 | best=  354 | reward=  -46.500 | policy=+0.0134 | value=34.0244 | entropy=6.4651 | KL=0.032539 | clipped=0.2943
# Iteration    146 | source=archive-score-any-to-399 | initial=  330 | final=  696 | best=  330 | reward=  -36.600 | policy=+0.0110 | value=41.3784 | entropy=6.6039 | KL=0.025030 | clipped=0.3438
# Iteration    147 | source=random                   | initial= 1440 | final=  910 | best=  892 | reward=  +53.000 | policy=-0.0169 | value=42.4698 | entropy=6.4612 | KL=0.020259 | clipped=0.2526
# Iteration    148 | source=archive-score-any-to-399 | initial=  354 | final=  749 | best=  354 | reward=  -39.500 | policy=+0.0024 | value=29.4362 | entropy=6.5046 | KL=0.016253 | clipped=0.2109
# Iteration    149 | source=archive-score-any-to-399 | initial=  331 | final=  684 | best=  331 | reward=  -35.300 | policy=-0.0211 | value=21.6643 | entropy=6.4570 | KL=0.014683 | clipped=0.2305 | checkpoint=ramsey_policy_iteration_000149.pt
# Iteration    150 | source=archive-score-any-to-399 | initial=  306 | final=  760 | best=  306 | reward=  -45.400 | policy=+0.0003 | value=34.9300 | entropy=6.4506 | KL=0.008134 | clipped=0.1035
# Iteration    151 | source=random                   | initial= 1939 | final=  996 | best=  945 | reward=  +94.300 | policy=+0.0006 | value=170.3589 | entropy=6.0827 | KL=0.020213 | clipped=0.2318
# Iteration    152 | source=archive-score-any-to-399 | initial=  383 | final=  740 | best=  383 | reward=  -35.700 | policy=+0.0434 | value=25.9469 | entropy=6.4486 | KL=0.124929 | clipped=0.6719
# Iteration    153 | source=archive-score-any-to-399 | initial=  388 | final=  725 | best=  388 | reward=  -33.700 | policy=+0.1114 | value=19.9427 | entropy=6.2357 | KL=0.081759 | clipped=0.6328
# Iteration    154 | source=random                   | initial= 1806 | final=  856 | best=  851 | reward=  +95.000 | policy=+0.0407 | value=153.8069 | entropy=6.3293 | KL=0.047183 | clipped=0.3438
# Iteration    155 | source=archive-score-any-to-399 | initial=  365 | final=  715 | best=  365 | reward=  -35.000 | policy=+0.0537 | value=19.5232 | entropy=6.0740 | KL=0.078410 | clipped=0.6250
# Iteration    156 | source=archive-score-any-to-399 | initial=  323 | final=  706 | best=  323 | reward=  -38.300 | policy=+0.0205 | value=29.9999 | entropy=6.4130 | KL=0.049517 | clipped=0.4922
# Iteration    157 | source=archive-score-any-to-399 | initial=  305 | final=  692 | best=  305 | reward=  -38.700 | policy=+0.0013 | value=22.5657 | entropy=6.2072 | KL=0.051327 | clipped=0.4844
# Iteration    158 | source=archive-score-any-to-399 | initial=  337 | final=  779 | best=  337 | reward=  -44.200 | policy=+0.0053 | value=34.1667 | entropy=6.2839 | KL=0.016623 | clipped=0.2344
# Iteration    159 | source=random                   | initial= 1881 | final=  968 | best=  953 | reward=  +91.300 | policy=+0.0350 | value=143.5867 | entropy=6.0157 | KL=0.045294 | clipped=0.5312 | checkpoint=ramsey_policy_iteration_000159.pt
# Iteration    160 | source=random                   | initial= 1619 | final=  832 | best=  816 | reward=  +78.700 | policy=-0.0028 | value=101.6307 | entropy=6.1470 | KL=0.037439 | clipped=0.3555
# Iteration    161 | source=archive-score-any-to-399 | initial=  329 | final=  708 | best=  329 | reward=  -37.900 | policy=+0.0076 | value=23.7231 | entropy=6.1643 | KL=0.045035 | clipped=0.4531
# Iteration    162 | source=random                   | initial= 2005 | final=  910 | best=  866 | reward= +109.500 | policy=-0.0063 | value=306.7405 | entropy=5.9536 | KL=0.014154 | clipped=0.1758
# Iteration    163 | source=archive-score-any-to-399 | initial=  347 | final=  808 | best=  347 | reward=  -46.100 | policy=+0.0285 | value=31.0099 | entropy=6.3963 | KL=0.037763 | clipped=0.3672
# Iteration    164 | source=random                   | initial= 1814 | final= 1002 | best=  985 | reward=  +81.200 | policy=-0.0040 | value=177.9937 | entropy=6.1344 | KL=0.015024 | clipped=0.1953
# Iteration    165 | source=random                   | initial= 1690 | final=  772 | best=  741 | reward=  +91.800 | policy=-0.0034 | value=151.5198 | entropy=6.1627 | KL=0.029110 | clipped=0.3789
# Iteration    166 | source=random                   | initial= 1575 | final=  986 | best=  975 | reward=  +58.900 | policy=+0.0364 | value=84.9124 | entropy=6.0729 | KL=0.031771 | clipped=0.4141
# Iteration    167 | source=random                   | initial= 1975 | final= 1034 | best=  944 | reward=  +94.100 | policy=-0.0005 | value=203.6075 | entropy=6.2046 | KL=0.030070 | clipped=0.3281
# Iteration    168 | source=archive-score-any-to-399 | initial=  318 | final=  840 | best=  318 | reward=  -52.200 | policy=+0.0012 | value=50.9815 | entropy=6.4049 | KL=0.015443 | clipped=0.2266
# Iteration    169 | source=random                   | initial= 1843 | final=  914 | best=  859 | reward=  +92.900 | policy=+0.0075 | value=140.3836 | entropy=6.0919 | KL=0.013845 | clipped=0.1719 | checkpoint=ramsey_policy_iteration_000169.pt
# Iteration    170 | source=archive-score-any-to-399 | initial=  349 | final=  796 | best=  349 | reward=  -44.700 | policy=-0.0005 | value=34.9275 | entropy=6.4128 | KL=0.040154 | clipped=0.4453
# Iteration    171 | source=archive-score-any-to-399 | initial=  369 | final=  662 | best=  369 | reward=  -29.300 | policy=+0.0170 | value=13.9314 | entropy=6.2116 | KL=0.030807 | clipped=0.4688
# Iteration    172 | source=random                   | initial= 2361 | final=  862 | best=  849 | reward= +149.900 | policy=+0.0074 | value=397.7505 | entropy=5.9691 | KL=0.016673 | clipped=0.2344
# Iteration    173 | source=archive-score-any-to-399 | initial=  322 | final=  651 | best=  322 | reward=  -32.900 | policy=+0.0061 | value=19.0688 | entropy=6.0816 | KL=0.042488 | clipped=0.3984
# Iteration    174 | source=archive-score-any-to-399 | initial=  327 | final=  785 | best=  327 | reward=  -45.800 | policy=+0.0170 | value=34.3871 | entropy=6.2659 | KL=0.038008 | clipped=0.4141
# Iteration    175 | source=archive-score-any-to-399 | initial=  298 | final=  698 | best=  298 | reward=  -40.000 | policy=+0.0731 | value=33.8968 | entropy=6.2646 | KL=0.039397 | clipped=0.4297
# Iteration    176 | source=archive-score-any-to-399 | initial=  314 | final=  762 | best=  314 | reward=  -44.800 | policy=-0.0210 | value=33.8171 | entropy=6.4603 | KL=0.016658 | clipped=0.2917
# Iteration    177 | source=archive-score-any-to-399 | initial=  320 | final=  758 | best=  320 | reward=  -43.800 | policy=+0.0016 | value=30.0032 | entropy=6.2988 | KL=0.018705 | clipped=0.2526
# Iteration    178 | source=archive-score-any-to-399 | initial=  318 | final=  702 | best=  318 | reward=  -38.400 | policy=+0.0001 | value=26.1879 | entropy=6.3671 | KL=0.020662 | clipped=0.3281
# Iteration    179 | source=archive-score-any-to-399 | initial=  305 | final=  744 | best=  305 | reward=  -43.900 | policy=-0.0076 | value=33.6101 | entropy=6.1655 | KL=0.021559 | clipped=0.3008 | checkpoint=ramsey_policy_iteration_000179.pt
# Iteration    180 | source=archive-score-any-to-399 | initial=  331 | final=  706 | best=  331 | reward=  -37.500 | policy=+0.0265 | value=26.2864 | entropy=6.0114 | KL=0.034557 | clipped=0.5078
# Iteration    181 | source=archive-score-any-to-399 | initial=  304 | final=  715 | best=  301 | reward=  -41.100 | policy=+0.0297 | value=28.2406 | entropy=6.1997 | KL=0.026178 | clipped=0.3906
# Iteration    182 | source=archive-score-any-to-399 | initial=  334 | final=  712 | best=  334 | reward=  -37.800 | policy=+0.0093 | value=21.5518 | entropy=6.1120 | KL=0.025710 | clipped=0.3164
# Iteration    183 | source=random                   | initial= 1751 | final=  855 | best=  812 | reward=  +89.600 | policy=-0.0138 | value=178.7081 | entropy=5.9476 | KL=0.016351 | clipped=0.2109
# Iteration    184 | source=random                   | initial= 2002 | final=  865 | best=  853 | reward= +113.700 | policy=+0.0171 | value=253.2039 | entropy=6.0042 | KL=0.023554 | clipped=0.2266
# Iteration    185 | source=archive-score-any-to-399 | initial=  307 | final=  787 | best=  307 | reward=  -48.000 | policy=+0.0220 | value=33.8531 | entropy=6.1549 | KL=0.035199 | clipped=0.4141
# Iteration    186 | source=archive-score-any-to-399 | initial=  328 | final=  715 | best=  328 | reward=  -38.700 | policy=+0.0243 | value=24.7441 | entropy=6.0808 | KL=0.020625 | clipped=0.3672
# Iteration    187 | source=random                   | initial= 1766 | final=  840 | best=  840 | reward=  +92.600 | policy=+0.0001 | value=157.8555 | entropy=6.0368 | KL=0.015932 | clipped=0.2305
# Iteration    188 | source=archive-score-any-to-399 | initial=  353 | final=  735 | best=  353 | reward=  -38.200 | policy=-0.0173 | value=29.8667 | entropy=6.2325 | KL=0.012549 | clipped=0.1777
# Iteration    189 | source=archive-score-any-to-399 | initial=  333 | final=  665 | best=  333 | reward=  -33.200 | policy=+0.0081 | value=18.4530 | entropy=6.1795 | KL=0.016848 | clipped=0.2656 | checkpoint=ramsey_policy_iteration_000189.pt
# Iteration    190 | source=archive-score-any-to-399 | initial=  323 | final=  770 | best=  323 | reward=  -44.700 | policy=+0.0146 | value=29.3065 | entropy=6.1904 | KL=0.029106 | clipped=0.3711
# Iteration    191 | source=archive-score-any-to-399 | initial=  306 | final=  621 | best=  306 | reward=  -31.500 | policy=+0.0620 | value=19.2809 | entropy=6.0578 | KL=0.080570 | clipped=0.4883
# Iteration    192 | source=archive-score-any-to-399 | initial=  340 | final=  685 | best=  340 | reward=  -34.500 | policy=+0.0620 | value=19.8213 | entropy=6.2257 | KL=0.093741 | clipped=0.6719
# Iteration    193 | source=archive-score-any-to-399 | initial=  323 | final=  694 | best=  323 | reward=  -37.100 | policy=+0.0394 | value=24.6469 | entropy=6.1328 | KL=0.027751 | clipped=0.3828
# Iteration    194 | source=random                   | initial= 2199 | final=  874 | best=  871 | reward= +132.500 | policy=-0.0126 | value=348.1900 | entropy=5.8472 | KL=0.013311 | clipped=0.1836
# Iteration    195 | source=random                   | initial= 1915 | final=  798 | best=  772 | reward= +111.700 | policy=-0.0019 | value=240.4634 | entropy=5.8514 | KL=0.033783 | clipped=0.4531
# Iteration    196 | source=archive-score-any-to-399 | initial=  356 | final=  787 | best=  356 | reward=  -43.100 | policy=+0.0021 | value=30.9719 | entropy=6.2711 | KL=0.033353 | clipped=0.3359
# Iteration    197 | source=archive-score-any-to-399 | initial=  354 | final=  751 | best=  354 | reward=  -39.700 | policy=+0.0060 | value=25.4900 | entropy=6.1999 | KL=0.014672 | clipped=0.2539
# Iteration    198 | source=archive-score-any-to-399 | initial=  313 | final=  696 | best=  313 | reward=  -38.300 | policy=+0.0014 | value=23.1073 | entropy=6.1377 | KL=0.015023 | clipped=0.2734
# Iteration    199 | source=archive-score-any-to-399 | initial=  321 | final=  724 | best=  321 | reward=  -40.300 | policy=-0.0107 | value=29.8558 | entropy=6.2372 | KL=0.013840 | clipped=0.2214 | checkpoint=ramsey_policy_iteration_000199.pt
# Iteration    200 | source=archive-score-any-to-399 | initial=  304 | final=  771 | best=  304 | reward=  -46.700 | policy=-0.0161 | value=32.2584 | entropy=6.1941 | KL=0.014298 | clipped=0.2305
# Iteration    201 | source=archive-score-any-to-399 | initial=  335 | final=  640 | best=  335 | reward=  -30.500 | policy=+0.0383 | value=19.8144 | entropy=6.1338 | KL=0.034884 | clipped=0.4375
# Iteration    202 | source=archive-score-any-to-399 | initial=  314 | final=  676 | best=  314 | reward=  -36.200 | policy=+0.0474 | value=26.0907 | entropy=6.2204 | KL=0.021494 | clipped=0.3906
# Iteration    203 | source=archive-score-any-to-399 | initial=  297 | final=  684 | best=  297 | reward=  -38.700 | policy=+0.0185 | value=27.5432 | entropy=6.2938 | KL=0.024872 | clipped=0.3164
# Iteration    204 | source=archive-score-any-to-399 | initial=  334 | final=  660 | best=  334 | reward=  -32.600 | policy=+0.0271 | value=15.5767 | entropy=6.3231 | KL=0.017625 | clipped=0.2383
# Iteration    205 | source=random                   | initial= 1546 | final=  791 | best=  791 | reward=  +75.500 | policy=+0.0041 | value=105.7405 | entropy=6.1053 | KL=0.021222 | clipped=0.2500
# Iteration    206 | source=archive-score-any-to-399 | initial=  330 | final=  626 | best=  330 | reward=  -29.600 | policy=+0.0004 | value=19.1343 | entropy=6.2373 | KL=0.026416 | clipped=0.4180
# Iteration    207 | source=random                   | initial= 2176 | final=  857 | best=  845 | reward= +131.900 | policy=-0.0125 | value=381.9283 | entropy=6.0949 | KL=0.049391 | clipped=0.4297
# Iteration    208 | source=random                   | initial= 1859 | final=  765 | best=  759 | reward= +109.400 | policy=-0.0093 | value=205.5917 | entropy=6.0272 | KL=0.017145 | clipped=0.2682
# Iteration    209 | source=archive-score-any-to-399 | initial=  311 | final=  700 | best=  311 | reward=  -38.900 | policy=-0.0079 | value=32.1406 | entropy=6.2416 | KL=0.017665 | clipped=0.2578 | checkpoint=ramsey_policy_iteration_000209.pt
# Iteration    210 | source=random                   | initial= 1870 | final=  830 | best=  830 | reward= +104.000 | policy=-0.0139 | value=206.5307 | entropy=6.1341 | KL=0.022772 | clipped=0.2930
# Iteration    211 | source=archive-score-any-to-399 | initial=  317 | final=  695 | best=  317 | reward=  -37.800 | policy=-0.0013 | value=21.7741 | entropy=6.2530 | KL=0.037370 | clipped=0.3906
# Iteration    212 | source=archive-score-any-to-399 | initial=  354 | final=  759 | best=  354 | reward=  -40.500 | policy=-0.0167 | value=30.2872 | entropy=6.1291 | KL=0.015596 | clipped=0.2500
# Iteration    213 | source=random                   | initial= 2233 | final=  942 | best=  942 | reward= +129.100 | policy=-0.0094 | value=300.4101 | entropy=5.8465 | KL=0.020033 | clipped=0.2188
# Iteration    214 | source=archive-score-any-to-399 | initial=  298 | final=  672 | best=  298 | reward=  -37.400 | policy=-0.0117 | value=24.3946 | entropy=5.9708 | KL=0.013689 | clipped=0.1927
# Iteration    215 | source=archive-score-any-to-399 | initial=  305 | final=  712 | best=  305 | reward=  -40.700 | policy=-0.0207 | value=26.2683 | entropy=6.0243 | KL=0.025284 | clipped=0.2930
# Iteration    216 | source=archive-score-any-to-399 | initial=  322 | final=  636 | best=  322 | reward=  -31.400 | policy=-0.0158 | value=20.0034 | entropy=5.9617 | KL=0.014765 | clipped=0.2135
# Iteration    217 | source=archive-score-any-to-399 | initial=  321 | final=  688 | best=  321 | reward=  -36.700 | policy=+0.0397 | value=26.7446 | entropy=5.9144 | KL=0.044397 | clipped=0.4609
# Iteration    218 | source=archive-score-any-to-399 | initial=  347 | final=  738 | best=  347 | reward=  -39.100 | policy=-0.0028 | value=27.8929 | entropy=5.9894 | KL=0.020569 | clipped=0.2188
# Iteration    219 | source=archive-score-any-to-399 | initial=  289 | final=  580 | best=  289 | reward=  -29.100 | policy=-0.0109 | value=16.8026 | entropy=5.8938 | KL=0.014751 | clipped=0.1589 | checkpoint=ramsey_policy_iteration_000219.pt
# Iteration    220 | source=archive-score-any-to-399 | initial=  320 | final=  693 | best=  320 | reward=  -37.300 | policy=+0.0152 | value=20.4179 | entropy=5.9146 | KL=0.048514 | clipped=0.4219
# Iteration    221 | source=archive-score-any-to-399 | initial=  323 | final=  596 | best=  323 | reward=  -27.300 | policy=+0.0068 | value=16.5177 | entropy=5.8306 | KL=0.021284 | clipped=0.3008
# Iteration    222 | source=archive-score-any-to-399 | initial=  309 | final=  634 | best=  309 | reward=  -32.500 | policy=+0.0155 | value=21.9391 | entropy=5.8484 | KL=0.021708 | clipped=0.3984
# Iteration    223 | source=archive-score-any-to-399 | initial=  317 | final=  638 | best=  317 | reward=  -32.100 | policy=+0.0100 | value=16.6566 | entropy=5.8859 | KL=0.030615 | clipped=0.3672
# Iteration    224 | source=archive-score-any-to-399 | initial=  357 | final=  637 | best=  357 | reward=  -28.000 | policy=-0.0032 | value=13.5198 | entropy=5.8411 | KL=0.021424 | clipped=0.3333
# Iteration    225 | source=archive-score-any-to-399 | initial=  289 | final=  620 | best=  289 | reward=  -33.100 | policy=-0.0047 | value=18.9280 | entropy=5.7628 | KL=0.019439 | clipped=0.2266
# Iteration    226 | source=archive-score-any-to-399 | initial=  309 | final=  621 | best=  309 | reward=  -31.200 | policy=-0.0040 | value=18.4899 | entropy=5.7994 | KL=0.024886 | clipped=0.2891
# Iteration    227 | source=archive-score-any-to-399 | initial=  311 | final=  593 | best=  311 | reward=  -28.200 | policy=-0.0261 | value=14.1167 | entropy=5.7046 | KL=0.020446 | clipped=0.3281
# Iteration    228 | source=archive-score-any-to-399 | initial=  343 | final=  576 | best=  343 | reward=  -23.300 | policy=-0.0099 | value=10.4093 | entropy=5.5507 | KL=0.016907 | clipped=0.2539
# Iteration    229 | source=archive-score-any-to-399 | initial=  341 | final=  586 | best=  341 | reward=  -24.500 | policy=+0.0368 | value=11.9556 | entropy=5.4335 | KL=0.059847 | clipped=0.4844 | checkpoint=ramsey_policy_iteration_000229.pt
# Iteration    230 | source=archive-score-any-to-399 | initial=  304 | final=  498 | best=  304 | reward=  -19.400 | policy=+0.0515 | value=7.6565 | entropy=5.2136 | KL=0.063511 | clipped=0.5547
# Iteration    231 | source=archive-score-any-to-399 | initial=  304 | final=  526 | best=  302 | reward=  -22.200 | policy=+0.0394 | value=8.9391 | entropy=5.4414 | KL=0.028559 | clipped=0.4453
# Iteration    232 | source=random                   | initial= 1886 | final=  770 | best=  757 | reward= +111.600 | policy=+0.0542 | value=198.4196 | entropy=5.4287 | KL=0.033829 | clipped=0.5547
# Iteration    233 | source=archive-score-any-to-399 | initial=  316 | final=  515 | best=  316 | reward=  -19.900 | policy=+0.0262 | value=7.3376 | entropy=5.3372 | KL=0.046291 | clipped=0.5234
# Iteration    234 | source=archive-score-any-to-399 | initial=  302 | final=  557 | best=  302 | reward=  -25.500 | policy=+0.0581 | value=11.5836 | entropy=5.1497 | KL=0.069734 | clipped=0.5312
# Iteration    235 | source=archive-score-any-to-399 | initial=  372 | final=  537 | best=  372 | reward=  -16.500 | policy=+0.0155 | value=6.3813 | entropy=5.2719 | KL=0.039288 | clipped=0.5078
# Iteration    236 | source=archive-score-any-to-399 | initial=  315 | final=  557 | best=  315 | reward=  -24.200 | policy=-0.0001 | value=10.1673 | entropy=5.2725 | KL=0.025160 | clipped=0.3672
# Iteration    237 | source=archive-score-any-to-399 | initial=  324 | final=  550 | best=  324 | reward=  -22.600 | policy=-0.0107 | value=9.2077 | entropy=5.3526 | KL=0.037521 | clipped=0.5703
# Iteration    238 | source=archive-score-any-to-399 | initial=  311 | final=  593 | best=  311 | reward=  -28.200 | policy=+0.0281 | value=14.2128 | entropy=5.2107 | KL=0.036623 | clipped=0.4766
# Iteration    239 | source=archive-score-any-to-399 | initial=  332 | final=  554 | best=  332 | reward=  -22.200 | policy=+0.0403 | value=8.2291 | entropy=5.3046 | KL=0.078330 | clipped=0.4961 | checkpoint=ramsey_policy_iteration_000239.pt
# Iteration    240 | source=archive-score-any-to-399 | initial=  306 | final=  577 | best=  306 | reward=  -27.100 | policy=+0.0549 | value=10.9601 | entropy=5.2449 | KL=0.084615 | clipped=0.7188
# Iteration    241 | source=archive-score-any-to-399 | initial=  307 | final=  547 | best=  307 | reward=  -24.000 | policy=+0.0297 | value=10.4807 | entropy=5.1858 | KL=0.042051 | clipped=0.5547
# Iteration    242 | source=archive-score-any-to-399 | initial=  291 | final=  572 | best=  291 | reward=  -28.100 | policy=+0.0055 | value=13.7947 | entropy=5.1016 | KL=0.021298 | clipped=0.2188
# Iteration    243 | source=archive-score-any-to-399 | initial=  310 | final=  579 | best=  310 | reward=  -26.900 | policy=+0.0230 | value=13.7976 | entropy=5.0423 | KL=0.028879 | clipped=0.2969
# Iteration    244 | source=archive-score-any-to-399 | initial=  356 | final=  619 | best=  356 | reward=  -26.300 | policy=-0.0120 | value=13.0094 | entropy=4.9932 | KL=0.018393 | clipped=0.2500
# Iteration    245 | source=archive-score-any-to-399 | initial=  312 | final=  632 | best=  312 | reward=  -32.000 | policy=-0.0017 | value=17.9303 | entropy=4.9285 | KL=0.019759 | clipped=0.2461
# Iteration    246 | source=random                   | initial= 1728 | final=  858 | best=  848 | reward=  +87.000 | policy=-0.0174 | value=134.5365 | entropy=5.0100 | KL=0.021621 | clipped=0.2305
# Iteration    247 | source=archive-score-any-to-399 | initial=  330 | final=  543 | best=  330 | reward=  -21.300 | policy=+0.0050 | value=7.6692 | entropy=4.7307 | KL=0.028735 | clipped=0.4141
# Iteration    248 | source=random                   | initial= 1511 | final=  828 | best=  828 | reward=  +68.300 | policy=+0.0097 | value=94.6043 | entropy=4.9800 | KL=0.020465 | clipped=0.2578
# Iteration    249 | source=archive-score-any-to-399 | initial=  307 | final=  581 | best=  307 | reward=  -27.400 | policy=+0.0194 | value=14.8703 | entropy=4.9959 | KL=0.020244 | clipped=0.3203 | checkpoint=ramsey_policy_iteration_000249.pt
#
# Completed iterations: 250
# Best score: 286
# Solved: False
# Total time: 447.601 seconds
# Mean time per iteration: 1.790 seconds

# %%
# Compare Archive-Seed and Random-Seed Outcomes

for source_name in (
    archive_construction.name,
    random_construction.name,
):
    source_results = [
        item
        for item in training_result.iteration_results
        if item.construction_source == source_name
    ]

    if not source_results:
        print(source_name, "produced no iterations.")
        continue

    source_initial = np.asarray(
        [item.initial_score for item in source_results],
        dtype=np.float64,
    )

    source_best = np.asarray(
        [item.best_score for item in source_results],
        dtype=np.float64,
    )

    print()
    print("Source:", source_name)
    print("Iterations:", len(source_results))
    print("Mean initial:", f"{source_initial.mean():.2f}")
    print("Mean best:", f"{source_best.mean():.2f}")
    print(
        "Mean best reduction:",
        f"{(source_initial - source_best).mean():.2f}",
    )
    print("Source best:", int(source_best.min()))
# Out:
# Source: archive-score-any-to-399
# Iterations: 199
# Mean initial: 327.43
# Mean best: 327.33
# Mean best reduction: 0.10
# Source best: 286
#
# Source: random
# Iterations: 51
# Mean initial: 1879.53
# Mean best: 1200.29
# Mean best reduction: 679.24
# Source best: 741

# %%
# Plot Phase 3 Scores

iteration_numbers = np.asarray(
    [item.iteration for item in training_result.iteration_results]
)

initial_scores = np.asarray(
    [item.initial_score for item in training_result.iteration_results]
)

best_scores = np.asarray(
    [item.best_score for item in training_result.iteration_results]
)

running_best_scores = np.minimum.accumulate(
    best_scores
)

figure, axis = plt.subplots(
    figsize=(11, 5.5),
    constrained_layout=True,
)

axis.plot(
    iteration_numbers,
    initial_scores,
    label="initial",
    alpha=0.55,
)

axis.plot(
    iteration_numbers,
    best_scores,
    label="rollout best",
    alpha=0.85,
)

axis.plot(
    iteration_numbers,
    running_best_scores,
    label="run best",
    linewidth=2.5,
)

axis.axhline(
    ARCHIVE_SCORE_LIMIT,
    color="black",
    linestyle="--",
    alpha=0.5,
    label="Phase 3 entry threshold",
)

axis.set_xlabel("Training iteration")
axis.set_ylabel("Monochromatic K5 score")
axis.set_title(RUN_NAME)
axis.grid(linestyle="--", alpha=0.3)
axis.legend()

plt.show()

# %%
# Best Coloring and Updated Archive

best_iteration = training_result.best_iteration

print("Best iteration:", best_iteration.iteration)
print("Seed source:", best_iteration.construction_source)
print("Initial score:", best_iteration.initial_score)
print("Final score:", best_iteration.final_score)
print("Best score:", best_iteration.best_score)
print("Database best:", archive.best_score(graph))

plot_coloring_histogram(
    best_iteration.best_coloring,
    title=(
        f"Phase 3 best — iteration {best_iteration.iteration:,} — "
        f"score {best_iteration.best_score:,}"
    ),
)

plt.show()

print()
print("Archive leaderboard")

for record in archive.best_colorings(
    limit=10,
    graph=graph,
):
    print(
        f"ID={record.coloring_id:6d} | "
        f"score={record.score:5d} | "
        f"run={record.run_name} | "
        f"iteration={record.iteration:6d} | "
        f"seen={record.times_seen}"
    )

archive.close()
# Out:
# Best iteration: 113
# Seed source: archive-score-any-to-399
# Initial score: 286
# Final score: 873
# Best score: 286
# Database best: 278
# Archive leaderboard
# ID=  1735 | score=  278 | run=greedy-tabu-sub-400-phase-3-seeds-002 | iteration=   254 | seen=1
# ID=  1900 | score=  282 | run=greedy-tabu-sub-400-phase-3-seeds-002 | iteration=   461 | seen=1
# ID=  1892 | score=  284 | run=greedy-tabu-sub-400-phase-3-seeds-002 | iteration=   453 | seen=1
# ID=  1246 | score=  286 | run=phase-3-sub-400-curriculum | iteration=   113 | seen=5
# ID=  1573 | score=  286 | run=greedy-tabu-sub-400-phase-3-seeds-002 | iteration=    44 | seen=1
# ID=  1544 | score=  289 | run=phase-3-sub-400-curriculum | iteration=   219 | seen=2
# ID=  1546 | score=  289 | run=greedy-tabu-sub-400-phase-3-seeds-002 | iteration=   235 | seen=2
# ID=  1565 | score=  289 | run=phase-3-sub-400-curriculum | iteration=   225 | seen=2
# ID=  1755 | score=  289 | run=greedy-tabu-sub-400-phase-3-seeds-002 | iteration=   275 | seen=1
# ID=  1540 | score=  290 | run=greedy-tabu-sub-400-phase-3-seeds-002 | iteration=     2 | seen=1
